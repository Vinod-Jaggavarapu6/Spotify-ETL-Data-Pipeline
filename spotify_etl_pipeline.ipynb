# %%
# !pip install spotipy

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="0c7f3e757f8345c3ab6c079918879a41", client_secret="1876836e53414bc0887b1e443182147a")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/2a4YYkZa1c4ah4KFSGw5u5"

# %%
playlist_URI = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2a4YYkZa1c4ah4KFSGw5u5/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-09-07T02:34:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qvx2rye4bxeprajyebe4bns8c'},
#     'href': 'https://api.spotify.com/v1/users/qvx2rye4bxeprajyebe4bns8c',
#     'id': 'qvx2rye4bxeprajyebe4bns8c',
#     'type': 'user',
#     'uri': 'spotify:user:qvx2rye4bxeprajyebe4bns8c'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
# ...

# %%
print(len(data['items']))
# Out:
# 100

# %%
data['items'][0]['track']['album']['id']
# Out:
# '1Ac8fcWoMbo35vD3B5Tjqs'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Brown Munde'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-09-18'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1Ac8fcWoMbo35vD3B5Tjqs'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 254400

# %%
data['items'][0]['track']['popularity']
# Out:
# 68

# %%
artists = [artist['name'] for artist in data['items'][0]['track']['artists']]

artists

# %%
album_list = []

for track in data['items']:
    
    album_id = track['track']['album']['id']
    album_name = track['track']['album']['name']
    album_release_date = track['track']['album']['release_date']
    album_total_tracks = track['track']['album']['total_tracks']
    album_url = track['track']['album']['external_urls']['spotify']
    # album_duration_ms = track['track']['duration_ms']
    # album_popularity = track['track']['popularity']
    # album_artists = [artist['name'] for artist in data['items'][0]['track']['artists']]

    album = {"album_id":album_id, "album_name":album_name, "release_date":album_release_date, "total_tracks":album_total_tracks,"album_url":album_url}

    album_list.append(album)

# %%
album_list
# Out:
# [{'album_id': '1Ac8fcWoMbo35vD3B5Tjqs',
#   'album_name': 'Brown Munde',
#   'release_date': '2020-09-18',
#   'total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1Ac8fcWoMbo35vD3B5Tjqs'},
#  {'album_id': '3uuu6u13U0KeVQsZ3CZKK4',
#   'album_name': 'Kabir Singh',
#   'release_date': '2019-06-14',
#   'total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/3uuu6u13U0KeVQsZ3CZKK4'},
#  {'album_id': '4nZOPP0atfJbBlkedLYi7t',
#   'album_name': 'Bajrangi Bhaijaan',
#   'release_date': '2015-07-07',
#   'total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/4nZOPP0atfJbBlkedLYi7t'},
#  {'album_id': '3Ha8CM9px7D2fn25K4ijl6',
#   'album_name': 'OK Jaanu (Original Motion Picture Soundtrack)',
#   'release_date': '2017-01-04',
#   'total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/3Ha8CM9px7D2fn25K4ijl6'},
#  {'album_id': '4Vyb6DpCBuDYJFgnByGq3A',
#   'album_name': 'Mere Sohneya (From "Kabir Singh")',
#   'release_date': '2019-06-06',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LEG9Ld1aLImEFEVHdWNSB'},
#   'href': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB',
#   'id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'name': 'AP Dhillon',
#   'type': 'artist',
#   'uri': 'spotify:artist:6LEG9Ld1aLImEFEVHdWNSB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vvW590Gq8dNWsP5BM9FkS'},
#   'href': 'https://api.spotify.com/v1/artists/4vvW590Gq8dNWsP5BM9FkS',
#   'id': '4vvW590Gq8dNWsP5BM9FkS',
#   'name': 'Gminxr',
#   'type': 'artist',
#   'uri': 'spotify:artist:4vvW590Gq8dNWsP5BM9FkS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5DHi2MeoRgAwPE0A0qwRMl'},
#   'href': 'https://api.spotify.com/v1/artists/5DHi2MeoRgAwPE0A0qwRMl',
#   'id': '5DHi2MeoRgAwPE0A0qwRMl',
#   'name': 'Gurinder Gill',
#   'type': 'artist',
#   'uri': 'spotify:artist:5DHi2MeoRgAwPE0A0qwRMl'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aQfrWHwAcuY8IYItbChZh'},
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '6LEG9Ld1aLImEFEVHdWNSB'

# %%
artist_list = []

for track in data['items']:
    for key, value in track.items():
        if key == 'track':
            for artist in value['artists']:
                artist_data = {"artist_id": artist['id'],"artist_name":artist['name'],'artist_url':artist['href']}
                artist_list.append(artist_data)
artist_list
# Out:
# [{'artist_id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'artist_name': 'AP Dhillon',
#   'artist_url': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB'},
#  {'artist_id': '4vvW590Gq8dNWsP5BM9FkS',
#   'artist_name': 'Gminxr',
#   'artist_url': 'https://api.spotify.com/v1/artists/4vvW590Gq8dNWsP5BM9FkS'},
#  {'artist_id': '5DHi2MeoRgAwPE0A0qwRMl',
#   'artist_name': 'Gurinder Gill',
#   'artist_url': 'https://api.spotify.com/v1/artists/5DHi2MeoRgAwPE0A0qwRMl'},
#  {'artist_id': '6aQfrWHwAcuY8IYItbChZh',
#   'artist_name': 'Shinda Kahlon',
#   'artist_url': 'https://api.spotify.com/v1/artists/6aQfrWHwAcuY8IYItbChZh'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'artist_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'artist_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
# ...

# %%
song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '58f4twRnbZOOVUhMUpplJ4',
#   'song_name': 'Brown Munde',
#   'duration_ms': 254400,
#   'url': 'https://open.spotify.com/track/58f4twRnbZOOVUhMUpplJ4',
#   'popularity': 68,
#   'song_added': '2022-09-07T02:34:53Z',
#   'album_id': '1Ac8fcWoMbo35vD3B5Tjqs',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '47Il9B5GJ2FEkiwiIH3xX0',
#   'song_name': 'Bekhayali (Arijit Singh Version)',
#   'duration_ms': 370444,
#   'url': 'https://open.spotify.com/track/47Il9B5GJ2FEkiwiIH3xX0',
#   'popularity': 55,
#   'song_added': '2022-09-07T02:34:54Z',
#   'album_id': '3uuu6u13U0KeVQsZ3CZKK4',
#   'artist_id': '1SyKki7JI1AZNKwgNMkn25'},
#  {'song_id': '6TGX01ExmdHyOG72fqUU3Q',
#   'song_name': 'Zindagi Kuch Toh Bata (Reprise)',
#   'duration_ms': 258877,
#   'url': 'https://open.spotify.com/track/6TGX01ExmdHyOG72fqUU3Q',
#   'popularity': 61,
#   'song_added': '2023-04-13T09:15:44Z',
#   'album_id': '4nZOPP0atfJbBlkedLYi7t',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                     album_name  \
# 0  1Ac8fcWoMbo35vD3B5Tjqs                                    Brown Munde
# 1  3uuu6u13U0KeVQsZ3CZKK4                                    Kabir Singh
# 2  4nZOPP0atfJbBlkedLYi7t                              Bajrangi Bhaijaan
# 3  3Ha8CM9px7D2fn25K4ijl6  OK Jaanu (Original Motion Picture Soundtrack)
# 4  4Vyb6DpCBuDYJFgnByGq3A              Mere Sohneya (From "Kabir Singh")
#
#   release_date  total_tracks  \
# 0   2020-09-18             1
# 1   2019-06-14             9
# 2   2015-07-07            11
# 3   2017-01-04             8
# 4   2019-06-06             1
#
#                                            album_url
# 0  https://open.spotify.com/album/1Ac8fcWoMbo35vD...
# 1  https://open.spotify.com/album/3uuu6u13U0KeVQs...
# 2  https://open.spotify.com/album/4nZOPP0atfJbBlk...
# 3  https://open.spotify.com/album/3Ha8CM9px7D2fn2...
# 4  https://open.spotify.com/album/4Vyb6DpCBuDYJFg...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   album_name    100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   album_url     100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df.drop_duplicates(subset=['album_id'])
# Out:
#                   album_id                                         album_name  \
# 0   1Ac8fcWoMbo35vD3B5Tjqs                                        Brown Munde
# 1   3uuu6u13U0KeVQsZ3CZKK4                                        Kabir Singh
# 2   4nZOPP0atfJbBlkedLYi7t                                  Bajrangi Bhaijaan
# 3   3Ha8CM9px7D2fn25K4ijl6      OK Jaanu (Original Motion Picture Soundtrack)
# 4   4Vyb6DpCBuDYJFgnByGq3A                  Mere Sohneya (From "Kabir Singh")
# ..                     ...                                                ...
# 94  6zwucxlWusEUCZt6DeQJCu                      Deva Deva (From "Brahmastra")
# 95  3PxXJhlxSQkj8JO7IXy0FE  Hasee Toh Phasee (Original Motion Picture Soun...
# 96  5b7lWuBahHJ8dnNj3jKtCf                                              Safar
# 97  1nIe4xtu5pwjRLgegOYdMm                           Jab Koi Baat - Recreated
# 99  60qxoftYE2VOmZwIL9N2Cu                          Naah Goriye (From "Bala")
#
#    release_date  total_tracks  \
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    240 non-null    object
#  1   artist_name  240 non-null    object
#  2   artist_url   240 non-null    object
# dtypes: object(3)
# memory usage: 5.8+ KB

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  6LEG9Ld1aLImEFEVHdWNSB     AP Dhillon
# 1  4vvW590Gq8dNWsP5BM9FkS         Gminxr
# 2  5DHi2MeoRgAwPE0A0qwRMl  Gurinder Gill
# 3  6aQfrWHwAcuY8IYItbChZh  Shinda Kahlon
# 4  4YRxDV8wJFPHPTeXepOstw   Arijit Singh
#
#                                           artist_url
# 0  https://api.spotify.com/v1/artists/6LEG9Ld1aLI...
# 1  https://api.spotify.com/v1/artists/4vvW590Gq8d...
# 2  https://api.spotify.com/v1/artists/5DHi2MeoRgA...
# 3  https://api.spotify.com/v1/artists/6aQfrWHwAcu...
# 4  https://api.spotify.com/v1/artists/4YRxDV8wJFP...

# %%
artist_df.drop_duplicates(subset=['artist_id'])
# Out:
#                   artist_id       artist_name  \
# 0    6LEG9Ld1aLImEFEVHdWNSB        AP Dhillon
# 1    4vvW590Gq8dNWsP5BM9FkS            Gminxr
# 2    5DHi2MeoRgAwPE0A0qwRMl     Gurinder Gill
# 3    6aQfrWHwAcuY8IYItbChZh     Shinda Kahlon
# 4    4YRxDV8wJFPHPTeXepOstw      Arijit Singh
# ..                      ...               ...
# 232  2LgKrgRJcbJlt14i1LTzDU       Amit Mishra
# 234  2bfyLSCw72lQ5qoD8cdVBB  Sreerama Chandra
# 235  2UwDJeoMqYers5Jmm75zm2      Antara Mitra
# 238  7r7WoKowe8dCfQCl9GACDM      Swasti Mehul
# 239  5gZhfbckaWo89OzDSk3gdT             Jaani
#
#                                             artist_url
# 0    https://api.spotify.com/v1/artists/6LEG9Ld1aLI...
# 1    https://api.spotify.com/v1/artists/4vvW590Gq8d...
# 2    https://api.spotify.com/v1/artists/5DHi2MeoRgA...
# 3    https://api.spotify.com/v1/artists/6aQfrWHwAcu...
# 4    https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# ..                                                 ...
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df.head()
# Out:
#                   song_id                          song_name  duration_ms  \
# 0  58f4twRnbZOOVUhMUpplJ4                        Brown Munde       254400
# 1  47Il9B5GJ2FEkiwiIH3xX0   Bekhayali (Arijit Singh Version)       370444
# 2  6TGX01ExmdHyOG72fqUU3Q    Zindagi Kuch Toh Bata (Reprise)       258877
# 3  6bdpj89aYEBjhpsenXAsmO                          Enna Sona       213632
# 4  2IoZMG3RqiTmsy7Li3zGFg  Mere Sohneya (From "Kabir Singh")       193355
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/58f4twRnbZOOVUh...          68
# 1  https://open.spotify.com/track/47Il9B5GJ2FEkiw...          55
# 2  https://open.spotify.com/track/6TGX01ExmdHyOG7...          61
# 3  https://open.spotify.com/track/6bdpj89aYEBjhps...          66
# 4  https://open.spotify.com/track/2IoZMG3RqiTmsy7...          73
#
#              song_added                album_id               artist_id
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'],errors='coerce')
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   album_name    100 non-null    object
#  2   release_date  99 non-null     datetime64[ns]
#  3   total_tracks  100 non-null    int64
#  4   album_url     100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'],errors='coerce')
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
